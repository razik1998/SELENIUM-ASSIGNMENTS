# %%
#   Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, 
#        Term of office, Remarks) from https://www.jagranjosh.com/.

# %%
#  IMPORTING REQUIRED LABRARIES

import selenium 
import pandas as pd 
from selenium import webdriver
import warnings
warnings.filterwarnings ('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#  CONNECTING TO THE DRIVER
driver=webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver.exe")

# %%
#  OPENING THE JAGRANJOSH PAGE ON AUTOMATED CHROME BROWSER
driver.get("https://www.jagranjosh.com/.")

# %%
#  CLICKING ON GK
search = driver.find_element (By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[9]/a")
search.click()

# %%
#  CLICKING ON PRIME MINISTER OF INDIA
search = driver.find_element (By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]")
search.click()

# %%
#  CREATING EMPTY LIST
NAMES =[]
BORN_DEAD =[]
TERM_OFFICE =[]
REMARK = []

# %%
# SCRAPING NAMES 
prime = driver.find_elements (By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for i in prime :
    name = (i.text)
    NAMES.append (name)
    
    
    
# SCRAPING BORD DEAD 
born = driver.find_elements (By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in born :
    dead = (i.text)
    BORN_DEAD.append (dead)
    
    
    
# SCRAPING TERMS OF OFFICE
term = driver.find_elements (By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p')
for i in term [0:18]:
    office = (i.text)
    TERM_OFFICE.append (office)
    
    
    
# SCRAPING REMARKS
remarks = driver.find_elements (By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in remarks :
    mark = (i.text)
    REMARK.append (mark)

# %%
# printing lenghts of elements
print(len(NAMES),len(BORN_DEAD),len(TERM_OFFICE),len(REMARK))
# Out:
# 18 18 18 18

# %%
# MAKING DATA FRAME 
df = pd.DataFrame ({'NAMES':NAMES,'BORN_DEAD':BORN_DEAD,'TERM_OFFICE':TERM_OFFICE,'REMARK':REMARK})
df
# Out:
#                           NAMES     BORN_DEAD  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                            TERM_OFFICE  \
# ...
